# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=['question', 'section', 'answer'],
    keyword_fields=['course'],
    db_path='faq.db'
)

# %%
from rag_helper import RAGBase
from openai import OpenAI
import os

github_token = os.environ.get("GITHUB_LLM_TOKEN")

client = OpenAI(
    base_url="https://models.inference.ai.azure.com",
    api_key=github_token
)

# %% [markdown]
# With function calling (added tools to llm in RAGBase)

# %%
assistant = RAGBase (index = sqlite_index, llm_client= client, model = 'gpt-4o-mini')

# %%
answer = assistant.rag('Can I still join the course after it started?')
print(answer)
# Out:
# Agent decided to execute tool call
# 📡 [Executing Tool] Searching index for: 'join the course after it started'
# Yes, you can still join the course after it has started. However, if you want to receive a certificate, you need to submit your project while submissions are still being accepted.

# %%
answer = assistant.rag('How to start Olama')
print(answer)
# Out:
# Agent decided to execute tool call
# 📡 [Executing Tool] Searching index for: 'start Olama'
# I don't know.

# %%
answer = assistant.rag('When does the urse start?')
print(answer)
# Out:
# Agent decided to execute tool call
# 📡 [Executing Tool] Searching index for: 'course start date'
# I don't know.

# %%
answer = assistant.rag('Can I still join the course after it rted?')
print(answer)
# Out:
# Agent decided to execute tool call
# 📡 [Executing Tool] Searching index for: 'join the course after it started'
# Yes, you can still join the course after it has started, but you need to submit your project while submissions are still being accepted if you want to receive a certificate.

# %%
answer = assistant.rag('Waz iz the kurs abt?')
print(answer)
# Out:
# Agent decided to execute tool call
# 📡 [Executing Tool] Searching index for: 'course description'
# I don't know.

# %%
answer = assistant.rag('Waz iz the kurs name and how lang wil it b?')
print(answer)
# Out:
# Agent decided to execute tool call
# 📡 [Executing Tool] Searching index for: 'course name and duration'
# I don't know.

# %%
answer = assistant.rag('who is conducting this course')
print(answer)
# Out:
# Agent decided to execute tool call
# 📡 [Executing Tool] Searching index for: 'who is conducting this course'
# I don't know.
